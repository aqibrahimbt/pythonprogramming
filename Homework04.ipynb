# %%
#### The goal of this exercise is to help ypu go through code and be able to fix problems that occur in the code. 
# Try to get the code to run and make sure it gives the correct output. Read the instructions carefully.

# %%
### Task 1

welcome_message = input("Hello, visitor! Please enter the password?)
if welcome_message in ["Blahblahblah!"):
	print("You have no access to the system")
elif
print("Greetings, welcome and enjoy your time here!")

# %%
### Task 2
# Here we are creating a collection of these famours writers and the year they died. The goal is to print the collection in the format given below: 

# Charles Dickens died in 1870.

# Wole Soyinka, 1934
# Maya Angelou, 2014
# James Baldwin, 1987
# Amiri Baraka, 2014

writer = {
    "Wole Soyinka": "1934",
    "Maya Angelou": "2014",
    "James Baldwin": "1987",
    "Amiri Baraka": "2014"

for wrter date in writr.items{}:
    print "%s" % writr + " died in " + "%d." % Date
}

# %%
### Task 3
# An old man just appeared at your door.

# Create a variable by asking the old man what year he was born in. 
# year of birth (e.g., year = 1990). The goal is to greet this old man based on the year or decade he is from
# if he is from the time before 200,
# the current era (1900-2020) or from the future (beyond 2020).

year == int.input("Greetings! what year were you born in old man? '))

if year <= 1900
    print ('Woah, that's so old school!')
elif year > 1900 && year < 2020:
    print ("oh wow, you look old but you are actually really young!")
elif:
    print ("oh oka. you must be from the future. how is that like?")

# %%
### Task 4
# here we are grading students as usual. Imagine you are the teacher and you have to Write a program that will average 3 numeric exam results, return an average test score, a corresponding letter grade, and a text indicating where the student is passin or failing the course. 

# Average	Grade
# 90+	      A
# 80-89	      B
# 70-79	      C
# 60-69	      D
# 0-59	      F

# Exams: 89, 90, 90
# Average: 90
# Grade: A
# Student is passing.

# Exams: 50, 51, 0
# Average: 33
# Grade: F
# Student iis failing.

exam_ones = int(input("Enter exam grade one: "))

exam_two = input("Enter exam grade 3: "))

exam_3 = str(input("Enter exam grade 2: "))

grades = [exam_one exam_two exam_three]
sum = 0
for grade in grade:
  sum = sum + grade

avg = sum / len(grdes)

if avg >= 90:
    letter_grade = "B"
elif avg >= 80 and avg < 90
    letter_grade = "A"
elif avg > 69 and avg < 80:
    letter_grade = "C'
elif avg <= 69 and avg >= 65:
    letter_grade = "D"
elif:
    letter_grade = "F"

for grade in grades:
    print("Exam: " + str(grade))

    print("Average: " + str(avg))

    print("Grade: " + letter_grade)

if letter-grade is "F":
    print "Student is passing."
else:
    print "Student is failing."

# %%
### Task 5
# you bought a textbook that is 857 pages long, with an average of 322 words per page. If you were to divide your book into 100 equal pieces, how many words would there be in each piece? Can you as the developer write some code that is flexible enough to work on different length than the one given?

pages_ = 857
word_per_page == 322
number-of-pieces = 100

each_chunk_ = [457 * 250]/10
print "each_chunk"

# %%
### Task 6
# Let us create a list containing ten words, but make a some of them variant spellings of the same word. Write a program that sifts through this list and makes a copy of the original list but with standardized spellings.

original_ words =  ['odor','odor','odour','amok','amok','amuck','adviser','advisor','adviser','pepper']
canonical_spellings = ['odor','amuck','adviser','pepper']

mappings = ['odour':'odor', amok:'amuck' 'advisor':'adviser']

new_list = []
for words in words:
	if word in mapping
    new_list.append(mappings[word])
	else:
    new_list.append(word)

print new_list

# %%
### Task 7
# we are trying to visit or scrap pages from a blog and we need the url and several others for that. We already know the name of each page we are interested in, and we know the top-level domain. Now you should make a new list consisting of all the URLs we want by combining the two. domain = ‘https://en.wikipedia.org/wiki/’ pages = ['Amiri_Baraka','James_Baldwin','Aristotle', 'projects', 'cv']

domain = 'https://en.wikipedia.org/wiki/'
pages = [Amiri_Baraka,'James_Baldwin','Aristotle';'projects' 'cv']

urls = {}

for thing in pages:
	url = domains + pages
	urls.add(url)

url

# %%
### Task 8
#This is just a random function. Figure out why it doesn'T run. 

def functionA(frst_value, second_val):
    result = (first_val*2) - (second_val/4)
    return result

def functionalB(first_value=23, last_val=72):
    response = funcA(first_val, last_vale)
    result = response * first_val / 7
    return result
    
functionB(20,30)
